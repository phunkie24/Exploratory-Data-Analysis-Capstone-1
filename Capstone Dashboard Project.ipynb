# %%
pip install dash pandas plotly
# Out:
# Requirement already satisfied: dash in c:\users\hp\anaconda3\lib\site-packages (2.14.1)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: plotly in c:\users\hp\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\hp\anaconda3\lib\site-packages (from dash) (4.4.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\hp\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\hp\anaconda3\lib\site-packages (from dash) (2.2.2)
# Requirement already satisfied: importlib-metadata in c:\users\hp\anaconda3\lib\site-packages (from dash) (4.11.3)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\lib\site-packages (from dash) (65.6.3)
# Requirement already satisfied: ansi2html in c:\users\hp\anaconda3\lib\site-packages (from dash) (1.8.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\hp\anaconda3\lib\site-packages (from dash) (2.2.2)
# Requirement already satisfied: retrying in c:\users\hp\anaconda3\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\hp\anaconda3\lib\site-packages (from dash) (1.5.6)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from dash) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\hp\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.0.4)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\hp\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hp\anaconda3\lib\site-packages (from Werkzeug<3.1->dash) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\hp\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->dash) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->dash) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->dash) (3.4)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click>=8.0->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px

# Load the SpaceX data
spacex_csv_file = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
spacex_df = pd.read_csv(spacex_csv_file)

# Initialize the Dash app
app = dash.Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1("SpaceX Launch Data Analysis"),
    
    # Task 1: Launch Site Drop-down Input Component
    html.Label("Select Launch Site:"),
    dcc.Dropdown(
        id='launch-site-dropdown',
        options=[{'label': site, 'value': site} for site in spacex_df['Launch Site'].unique()],
        value=spacex_df['Launch Site'].iloc[0],  # Default value
        multi=False
    ),

    # Task 2: Success Pie Chart
    dcc.Graph(id='success-pie-chart'),

    # Task 3: Range Slider for Payload
    html.Label("Select Payload Range:"),
    dcc.RangeSlider(
        id='payload-range-slider',
        min=spacex_df['Payload Mass (kg)'].min(),
        max=spacex_df['Payload Mass (kg)'].max(),
        step=100,
        marks={i: str(i) for i in range(int(spacex_df['Payload Mass (kg)'].min()), int(spacex_df['Payload Mass (kg)'].max()) + 1, 500)},
        value=[spacex_df['Payload Mass (kg)'].min(), spacex_df['Payload Mass (kg)'].max()],
    ),

    # Task 4: Success Payload Scatter Chart
    dcc.Graph(id='success-payload-scatter-chart'),

])

# Task 2: Callback for Success Pie Chart
@app.callback(
    Output('success-pie-chart', 'figure'),
    [Input('launch-site-dropdown', 'value')]
)
def update_pie_chart(selected_site):
    filtered_df = spacex_df[spacex_df['Launch Site'] == selected_site]
    success_counts = filtered_df['Class'].value_counts()
    fig = px.pie(success_counts, names=success_counts.index, title=f'Successful Launches at {selected_site}')
    return fig

# Task 4: Callback for Success Payload Scatter Chart
@app.callback(
    Output('success-payload-scatter-chart', 'figure'),
    [Input('launch-site-dropdown', 'value'),
     Input('payload-range-slider', 'value')]
)
def update_scatter_chart(selected_site, payload_range):
    filtered_df = spacex_df[(spacex_df['Launch Site'] == selected_site) & 
                             (spacex_df['Payload Mass (kg)'].between(payload_range[0], payload_range[1]))]
    fig = px.scatter(filtered_df, x='Payload Mass (kg)', y='Class', color='Class', 
                     title=f'Successful Launches vs Payload Mass at {selected_site}')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(
#     self=Index(['Flight Number', 'Date', 'Time (UTC)', 'B...   'class', 'Lat', 'Long'],
#       dtype='object'),
#     key='Class'
# )
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#         casted_key = 'Class'
#         self = Index(['Flight Number', 'Date', 'Time (UTC)', 'Booster Version', 'Launch Site',
#        'Payload', 'Payload Mass (kg)', 'Orbit', 'Customer', 'Landing Outcome',
#        'class', 'Lat', 'Long'],
#       dtype='object')
#    3654 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# KeyError: 'Class'
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py:66, in scatter(
#     data_frame=    Flight Number        Date Time (UTC) Booster...02 -80.577356
# 25      1  28.562302 -80.577356  ,
#     x='Payload Mass (kg)',
#     y='Class',
#     color='Class',
#     symbol=None,
#     size=None,
#     hover_name=None,
#     hover_data=None,
#     custom_data=None,
#     text=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     error_x=None,
#     error_x_minus=None,
#     error_y=None,
#     error_y_minus=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     orientation=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale=None,
#     range_color=None,
#     color_continuous_midpoint=None,
#     symbol_sequence=None,
#     symbol_map=None,
#     opacity=None,
#     size_max=None,
#     marginal_x=None,
#     marginal_y=None,
#     trendline=None,
#     trendline_options=None,
#     trendline_color_override=None,
#     trendline_scope='trace',
#     log_x=False,
#     log_y=False,
#     range_x=None,
#     range_y=None,
#     render_mode='auto',
#     title='Successful Launches vs Payload Mass at CCAFS LC-40',
#     template=None,
#     width=None,
#     height=None
# )
#      12 def scatter(
#      13     data_frame=None,
#      14     x=None,
#    (...)
#      60     height=None,
#      61 ) -> go.Figure:
#      62     """
#      63     In a scatter plot, each row of `data_frame` is represented by a symbol
#      64     mark in 2D space.
#      65     """
# ---> 66     return make_figure(args=locals(), constructor=go.Scatter)
#         go = <module 'plotly.graph_objs' from 'C:\\Users\\HP\\anaconda3\\lib\\site-packages\\plotly\\graph_objs\\__init__.py'>
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1990, in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Class', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':     Flight Number        Date Time (UTC) Booster...02 -80.577356
# 25      1  28.562302 -80.577356  , ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>,
#     trace_patch={},
#     layout_patch={}
# )
#    1987 layout_patch = layout_patch or {}
#    1988 apply_default_cascade(args)
# -> 1990 args = build_dataframe(args, constructor)
#         args = {'data_frame':     Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0               1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1               2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2               3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3               4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4               5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
# 5               7  2013-12-03   22:41:00         F9 v1.1  CCAFS LC-40
# 6               8  2014-01-06   22:06:00         F9 v1.1  CCAFS LC-40
# 7               9  2014-04-18   19:25:00         F9 v1.1  CCAFS LC-40
# 8              10  2014-07-14   15:15:00         F9 v1.1  CCAFS LC-40
# 9              11  2014-08-05    8:00:00         F9 v1.1  CCAFS LC-40
# 10             12  2014-09-07    5:00:00   F9 v1.1 B1011  CCAFS LC-40
# 11             13  2014-09-21    5:52:00   F9 v1.1 B1010  CCAFS LC-40
# 12             14  2015-01-10    9:47:00   F9 v1.1 B1012  CCAFS LC-40
# 13             15  2015-02-11   23:03:00   F9 v1.1 B1013  CCAFS LC-40
# 14             16  2015-03-02    3:50:00   F9 v1.1 B1014  CCAFS LC-40
# 15             17  2015-04-14   20:10:00   F9 v1.1 B1015  CCAFS LC-40
# 16             18  2015-04-27   23:03:00   F9 v1.1 B1016  CCAFS LC-40
# 17             19  2015-06-28   14:21:00   F9 v1.1 B1018  CCAFS LC-40
# 18             20  2015-12-22    1:29:00     F9 FT B1019  CCAFS LC-40
# 19             22  2016-03-04   23:35:00     F9 FT B1020  CCAFS LC-40
# 20             23  2016-04-08   20:43:00   F9 FT B1021.1  CCAFS LC-40
# 21             24  2016-05-06    5:21:00     F9 FT B1022  CCAFS LC-40
# 22             25  2016-05-27   21:39:00   F9 FT B1023.1  CCAFS LC-40
# 23             26  2016-06-15   14:29:00     F9 FT B1024  CCAFS LC-40
# 24             27  2016-07-18    4:45:00   F9 FT B1025.1  CCAFS LC-40
# 25             28  2016-08-14    5:26:00     F9 FT B1026  CCAFS LC-40
#
#                                               Payload  Payload Mass (kg)  \
# 0                Dragon Spacecraft Qualification Unit                0.0
# 1   Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                              Dragon demo flight C2+              525.0
# 3                                        SpaceX CRS-1              500.0
# 4                                        SpaceX CRS-2              677.0
# 5                                               SES-8             3170.0
# 6                                           Thaicom 6             3325.0
# 7                                        SpaceX CRS-3             2296.0
# 8             OG2 Mission 1  6 Orbcomm-OG2 satellites             1316.0
# 9                                           AsiaSat 8             4535.0
# 10                                          AsiaSat 6             4428.0
# 11                                       SpaceX CRS-4             2216.0
# 12                                       SpaceX CRS-5             2395.0
# 13                                             DSCOVR              570.0
# 14                         ABS-3A Eutelsat 115 West B             4159.0
# 15                                       SpaceX CRS-6             1898.0
# 16                       TürkmenÄlem 52°E / MonacoSAT             4707.0
# 17                                       SpaceX CRS-7             1952.0
# 18          OG2 Mission 2   11 Orbcomm-OG2 satellites             2034.0
# 19                                              SES-9             5271.0
# 20                                       SpaceX CRS-8             3136.0
# 21                                           JCSAT-14             4696.0
# 22                                          Thaicom 8             3100.0
# 23                         ABS-2A Eutelsat 117 West B             3600.0
# 24                                       SpaceX CRS-9             2257.0
# 25                                           JCSAT-16             4600.0
#
#            Orbit                            Customer          Landing Outcome  \
# 0            LEO                              SpaceX    Failure   (parachute)
# 1      LEO (ISS)                     NASA (COTS) NRO    Failure   (parachute)
# 2      LEO (ISS)                         NASA (COTS)               No attempt
# 3      LEO (ISS)                          NASA (CRS)               No attempt
# 4      LEO (ISS)                          NASA (CRS)               No attempt
# 5            GTO                                 SES               No attempt
# 6            GTO                             Thaicom               No attempt
# 7      LEO (ISS)                          NASA (CRS)       Controlled (ocean)
# 8            LEO                             Orbcomm       Controlled (ocean)
# 9            GTO                             AsiaSat               No attempt
# 10           GTO                             AsiaSat               No attempt
# 11     LEO (ISS)                          NASA (CRS)     Uncontrolled (ocean)
# 12     LEO (ISS)                          NASA (CRS)    Failure  (drone ship)
# 13  Sun–Earth L1            U.S. Air Force NASA NOAA       Controlled (ocean)
# 14           GTO                        ABS Eutelsat               No attempt
# 15     LEO (ISS)                          NASA (CRS)    Failure  (drone ship)
# 16           GTO  Turkmenistan National Space Agency               No attempt
# 17     LEO (ISS)                          NASA (CRS)  Precluded  (drone ship)
# 18           LEO                             Orbcomm    Success  (ground pad)
# 19           GTO                                 SES     Failure (drone ship)
# 20     LEO (ISS)                          NASA (CRS)    Success  (drone ship)
# 21           GTO              SKY Perfect JSAT Group     Success (drone ship)
# 22           GTO                             Thaicom    Success  (drone ship)
# 23           GTO                        ABS Eutelsat    Failure  (drone ship)
# 24     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 25           GTO              SKY Perfect JSAT Group     Success (drone ship)
#
#     class        Lat       Long
# 0       0  28.562302 -80.577356
# 1       0  28.562302 -80.577356
# 2       0  28.562302 -80.577356
# 3       0  28.562302 -80.577356
# 4       0  28.562302 -80.577356
# 5       0  28.562302 -80.577356
# 6       0  28.562302 -80.577356
# 7       0  28.562302 -80.577356
# 8       0  28.562302 -80.577356
# 9       0  28.562302 -80.577356
# 10      0  28.562302 -80.577356
# 11      0  28.562302 -80.577356
# 12      0  28.562302 -80.577356
# 13      0  28.562302 -80.577356
# 14      0  28.562302 -80.577356
# 15      0  28.562302 -80.577356
# 16      0  28.562302 -80.577356
# 17      1  28.562302 -80.577356
# 18      1  28.562302 -80.577356
# 19      0  28.562302 -80.577356
# 20      1  28.562302 -80.577356
# 21      1  28.562302 -80.577356
# 22      1  28.562302 -80.577356
# 23      0  28.562302 -80.577356
# 24      1  28.562302 -80.577356
# 25      1  28.562302 -80.577356  , 'x': 'Payload Mass (kg)', 'y': 'Class', 'color': 'Class', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'Successful Launches vs Payload Mass at CCAFS LC-40', 'template': None, 'width': None, 'height': None}
#         constructor = <class 'plotly.graph_objs._scatter.Scatter'>
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992     args = process_dataframe_hierarchy(args)
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Class', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':     Flight Number        Date Time (UTC) Booster...02 -80.577356
# 25      1  28.562302 -80.577356  , ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>
# )
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#         args = {'data_frame':     Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0               1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1               2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2               3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3               4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4               5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
# 5               7  2013-12-03   22:41:00         F9 v1.1  CCAFS LC-40
# 6               8  2014-01-06   22:06:00         F9 v1.1  CCAFS LC-40
# 7               9  2014-04-18   19:25:00         F9 v1.1  CCAFS LC-40
# 8              10  2014-07-14   15:15:00         F9 v1.1  CCAFS LC-40
# 9              11  2014-08-05    8:00:00         F9 v1.1  CCAFS LC-40
# 10             12  2014-09-07    5:00:00   F9 v1.1 B1011  CCAFS LC-40
# 11             13  2014-09-21    5:52:00   F9 v1.1 B1010  CCAFS LC-40
# 12             14  2015-01-10    9:47:00   F9 v1.1 B1012  CCAFS LC-40
# 13             15  2015-02-11   23:03:00   F9 v1.1 B1013  CCAFS LC-40
# 14             16  2015-03-02    3:50:00   F9 v1.1 B1014  CCAFS LC-40
# 15             17  2015-04-14   20:10:00   F9 v1.1 B1015  CCAFS LC-40
# 16             18  2015-04-27   23:03:00   F9 v1.1 B1016  CCAFS LC-40
# 17             19  2015-06-28   14:21:00   F9 v1.1 B1018  CCAFS LC-40
# 18             20  2015-12-22    1:29:00     F9 FT B1019  CCAFS LC-40
# 19             22  2016-03-04   23:35:00     F9 FT B1020  CCAFS LC-40
# 20             23  2016-04-08   20:43:00   F9 FT B1021.1  CCAFS LC-40
# 21             24  2016-05-06    5:21:00     F9 FT B1022  CCAFS LC-40
# 22             25  2016-05-27   21:39:00   F9 FT B1023.1  CCAFS LC-40
# 23             26  2016-06-15   14:29:00     F9 FT B1024  CCAFS LC-40
# 24             27  2016-07-18    4:45:00   F9 FT B1025.1  CCAFS LC-40
# 25             28  2016-08-14    5:26:00     F9 FT B1026  CCAFS LC-40
#
#                                               Payload  Payload Mass (kg)  \
# 0                Dragon Spacecraft Qualification Unit                0.0
# 1   Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                              Dragon demo flight C2+              525.0
# 3                                        SpaceX CRS-1              500.0
# 4                                        SpaceX CRS-2              677.0
# 5                                               SES-8             3170.0
# 6                                           Thaicom 6             3325.0
# 7                                        SpaceX CRS-3             2296.0
# 8             OG2 Mission 1  6 Orbcomm-OG2 satellites             1316.0
# 9                                           AsiaSat 8             4535.0
# 10                                          AsiaSat 6             4428.0
# 11                                       SpaceX CRS-4             2216.0
# 12                                       SpaceX CRS-5             2395.0
# 13                                             DSCOVR              570.0
# 14                         ABS-3A Eutelsat 115 West B             4159.0
# 15                                       SpaceX CRS-6             1898.0
# 16                       TürkmenÄlem 52°E / MonacoSAT             4707.0
# 17                                       SpaceX CRS-7             1952.0
# 18          OG2 Mission 2   11 Orbcomm-OG2 satellites             2034.0
# 19                                              SES-9             5271.0
# 20                                       SpaceX CRS-8             3136.0
# 21                                           JCSAT-14             4696.0
# 22                                          Thaicom 8             3100.0
# 23                         ABS-2A Eutelsat 117 West B             3600.0
# 24                                       SpaceX CRS-9             2257.0
# 25                                           JCSAT-16             4600.0
#
#            Orbit                            Customer          Landing Outcome  \
# 0            LEO                              SpaceX    Failure   (parachute)
# 1      LEO (ISS)                     NASA (COTS) NRO    Failure   (parachute)
# 2      LEO (ISS)                         NASA (COTS)               No attempt
# 3      LEO (ISS)                          NASA (CRS)               No attempt
# 4      LEO (ISS)                          NASA (CRS)               No attempt
# 5            GTO                                 SES               No attempt
# 6            GTO                             Thaicom               No attempt
# 7      LEO (ISS)                          NASA (CRS)       Controlled (ocean)
# 8            LEO                             Orbcomm       Controlled (ocean)
# 9            GTO                             AsiaSat               No attempt
# 10           GTO                             AsiaSat               No attempt
# 11     LEO (ISS)                          NASA (CRS)     Uncontrolled (ocean)
# 12     LEO (ISS)                          NASA (CRS)    Failure  (drone ship)
# 13  Sun–Earth L1            U.S. Air Force NASA NOAA       Controlled (ocean)
# 14           GTO                        ABS Eutelsat               No attempt
# 15     LEO (ISS)                          NASA (CRS)    Failure  (drone ship)
# 16           GTO  Turkmenistan National Space Agency               No attempt
# 17     LEO (ISS)                          NASA (CRS)  Precluded  (drone ship)
# 18           LEO                             Orbcomm    Success  (ground pad)
# 19           GTO                                 SES     Failure (drone ship)
# 20     LEO (ISS)                          NASA (CRS)    Success  (drone ship)
# 21           GTO              SKY Perfect JSAT Group     Success (drone ship)
# 22           GTO                             Thaicom    Success  (drone ship)
# 23           GTO                        ABS Eutelsat    Failure  (drone ship)
# 24     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 25           GTO              SKY Perfect JSAT Group     Success (drone ship)
#
#     class        Lat       Long
# 0       0  28.562302 -80.577356
# 1       0  28.562302 -80.577356
# 2       0  28.562302 -80.577356
# 3       0  28.562302 -80.577356
# 4       0  28.562302 -80.577356
# 5       0  28.562302 -80.577356
# 6       0  28.562302 -80.577356
# 7       0  28.562302 -80.577356
# 8       0  28.562302 -80.577356
# 9       0  28.562302 -80.577356
# 10      0  28.562302 -80.577356
# 11      0  28.562302 -80.577356
# 12      0  28.562302 -80.577356
# 13      0  28.562302 -80.577356
# 14      0  28.562302 -80.577356
# 15      0  28.562302 -80.577356
# 16      0  28.562302 -80.577356
# 17      1  28.562302 -80.577356
# 18      1  28.562302 -80.577356
# 19      0  28.562302 -80.577356
# 20      1  28.562302 -80.577356
# 21      1  28.562302 -80.577356
# 22      1  28.562302 -80.577356
# 23      0  28.562302 -80.577356
# 24      1  28.562302 -80.577356
# 25      1  28.562302 -80.577356  , 'x': 'Payload Mass (kg)', 'y': 'Class', 'color': 'Class', 'symbol': None, 'size': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'symbol_sequence': None, 'symbol_map': None, 'opacity': None, 'size_max': None, 'marginal_x': None, 'marginal_y': None, 'trendline': None, 'trendline_options': None, 'trendline_color_override': None, 'trendline_scope': 'trace', 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'render_mode': 'auto', 'title': 'Successful Launches vs Payload Mass at CCAFS LC-40', 'template': None, 'width': None, 'height': None}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~\anaconda3\lib\site-packages\plotly\express\_core.py:1207, in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Class', 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':     Flight Number        Date Time (UTC) Booster...02 -80.577356
# 25      1  28.562302 -80.577356  , ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1205         if argument == "index":
#    1206             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207         raise ValueError(err_msg)
#         err_msg = "Value of 'y' is not the name of a column in 'data_frame'. Expected one of ['Flight Number', 'Date', 'Time (UTC)', 'Booster Version', 'Launch Site', 'Payload', 'Payload Mass (kg)', 'Orbit', 'Customer', 'Landing Outcome', 'class', 'Lat', 'Long'] but received: Class"
#    1208 elif length and len(df_input[argument]) != length:
#    1209     raise ValueError(
#    1210         "All arguments should have the same length. "
#    1211         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1218         )
#    1219     )
#
# ValueError: Value of 'y' is not the name of a column in 'data_frame'. Expected one of ['Flight Number', 'Date', 'Time (UTC)', 'Booster Version', 'Launch Site', 'Payload', 'Payload Mass (kg)', 'Orbit', 'Customer', 'Landing Outcome', 'class', 'Lat', 'Long'] but received: Class

# %%
import pandas as pd

# Load the SpaceX data
spacex_csv_file = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
spacex_df = pd.read_csv(spacex_csv_file)
spacex_df
# Out:
#     Flight Number        Date Time (UTC) Booster Version   Launch Site  \
# 0               1  2010-06-04   18:45:00  F9 v1.0  B0003   CCAFS LC-40
# 1               2  2010-12-08   15:43:00  F9 v1.0  B0004   CCAFS LC-40
# 2               3  2012-05-22    7:44:00  F9 v1.0  B0005   CCAFS LC-40
# 3               4  2012-10-08    0:35:00  F9 v1.0  B0006   CCAFS LC-40
# 4               5  2013-03-01   15:10:00  F9 v1.0  B0007   CCAFS LC-40
# 5               7  2013-12-03   22:41:00         F9 v1.1   CCAFS LC-40
# 6               8  2014-01-06   22:06:00         F9 v1.1   CCAFS LC-40
# 7               9  2014-04-18   19:25:00         F9 v1.1   CCAFS LC-40
# 8              10  2014-07-14   15:15:00         F9 v1.1   CCAFS LC-40
# 9              11  2014-08-05    8:00:00         F9 v1.1   CCAFS LC-40
# 10             12  2014-09-07    5:00:00   F9 v1.1 B1011   CCAFS LC-40
# 11             13  2014-09-21    5:52:00   F9 v1.1 B1010   CCAFS LC-40
# 12             14  2015-01-10    9:47:00   F9 v1.1 B1012   CCAFS LC-40
# 13             15  2015-02-11   23:03:00   F9 v1.1 B1013   CCAFS LC-40
# 14             16  2015-03-02    3:50:00   F9 v1.1 B1014   CCAFS LC-40
# 15             17  2015-04-14   20:10:00   F9 v1.1 B1015   CCAFS LC-40
# 16             18  2015-04-27   23:03:00   F9 v1.1 B1016   CCAFS LC-40
# 17             19  2015-06-28   14:21:00   F9 v1.1 B1018   CCAFS LC-40
# 18             20  2015-12-22    1:29:00     F9 FT B1019   CCAFS LC-40
# 19             22  2016-03-04   23:35:00     F9 FT B1020   CCAFS LC-40
# 20             23  2016-04-08   20:43:00   F9 FT B1021.1   CCAFS LC-40
# 21             24  2016-05-06    5:21:00     F9 FT B1022   CCAFS LC-40
# 22             25  2016-05-27   21:39:00   F9 FT B1023.1   CCAFS LC-40
# 23             26  2016-06-15   14:29:00     F9 FT B1024   CCAFS LC-40
# 24             27  2016-07-18    4:45:00   F9 FT B1025.1   CCAFS LC-40
# 25             28  2016-08-14    5:26:00     F9 FT B1026   CCAFS LC-40
# 26              6  2013-09-29   16:00:00  F9 v1.1  B1003   VAFB SLC-4E
# 27             21  2016-01-17   18:42:00   F9 v1.1 B1017   VAFB SLC-4E
# 28             29  2017-01-14   17:54:00   F9 FT B1029.1   VAFB SLC-4E
# 29             37  2017-06-25   20:25:00   F9 FT B1036.1   VAFB SLC-4E
# 30             40  2017-08-24   18:51:00   F9 FT B1038.1   VAFB SLC-4E
# 31             42  2017-10-09   12:37:00   F9 B4 B1041.1   VAFB SLC-4E
# 32             46  2017-12-23    1:27:00  F9 FT  B1036.2   VAFB SLC-4E
# 33             49  2018-02-22   14:17:00  F9 FT  B1038.2   VAFB SLC-4E
# 34             51  2018-03-30   14:14:00  F9 B4  B1041.2   VAFB SLC-4E
# 35             55  2018-05-22   19:47:58  F9 B4  B1043.2   VAFB SLC-4E
# 36             30  2017-02-19   14:39:00   F9 FT B1031.1    KSC LC-39A
# 37             31  2017-03-16    6:00:00     F9 FT B1030    KSC LC-39A
# 38             32  2017-03-30   22:27:00  F9 FT  B1021.2    KSC LC-39A
# 39             33  2017-05-01   11:15:00   F9 FT B1032.1    KSC LC-39A
# 40             34  2017-05-15   23:21:00     F9 FT B1034    KSC LC-39A
# 41             35  2017-06-03   21:07:00   F9 FT B1035.1    KSC LC-39A
# 42             36  2017-06-23   19:10:00  F9 FT  B1029.2    KSC LC-39A
# 43             38  2017-07-05   23:38:00     F9 FT B1037    KSC LC-39A
# 44             39  2017-08-14   16:31:00   F9 B4 B1039.1    KSC LC-39A
# 45             41  2017-09-07   14:00:00   F9 B4 B1040.1    KSC LC-39A
# 46             43  2017-10-11   22:53:00  F9 FT  B1031.2    KSC LC-39A
# 47             44  2017-10-30   19:34:00   F9 B4 B1042.1    KSC LC-39A
# 48             54  2018-05-11   20:14:00  F9 B5  B1046.1    KSC LC-39A
# 49             45  2017-12-15   15:36:00  F9 FT  B1035.2  CCAFS SLC-40
# 50             47  2018-01-08    1:00:00   F9 B4 B1043.1  CCAFS SLC-40
# 51             48  2018-01-31   21:25:00  F9 FT  B1032.2  CCAFS SLC-40
# 52             50  2018-03-06    5:33:00     F9 B4 B1044  CCAFS SLC-40
# 53             52  2018-04-02   20:30:00  F9 B4  B1039.2  CCAFS SLC-40
# 54             53  2018-04-18   22:51:00   F9 B4 B1045.1  CCAFS SLC-40
# 55             56  2018-06-04    4:45:00  F9 B4  B1040.2  CCAFS SLC-40
#
#                                               Payload  Payload Mass (kg)  \
# 0                Dragon Spacecraft Qualification Unit               0.00
# 1   Dragon demo flight C1, two CubeSats,  barrel o...               0.00
# 2                              Dragon demo flight C2+             525.00
# 3                                        SpaceX CRS-1             500.00
# 4                                        SpaceX CRS-2             677.00
# 5                                               SES-8            3170.00
# 6                                           Thaicom 6            3325.00
# 7                                        SpaceX CRS-3            2296.00
# 8             OG2 Mission 1  6 Orbcomm-OG2 satellites            1316.00
# 9                                           AsiaSat 8            4535.00
# 10                                          AsiaSat 6            4428.00
# 11                                       SpaceX CRS-4            2216.00
# 12                                       SpaceX CRS-5            2395.00
# 13                                             DSCOVR             570.00
# 14                         ABS-3A Eutelsat 115 West B            4159.00
# 15                                       SpaceX CRS-6            1898.00
# 16                       TürkmenÄlem 52°E / MonacoSAT            4707.00
# 17                                       SpaceX CRS-7            1952.00
# 18          OG2 Mission 2   11 Orbcomm-OG2 satellites            2034.00
# 19                                              SES-9            5271.00
# 20                                       SpaceX CRS-8            3136.00
# 21                                           JCSAT-14            4696.00
# 22                                          Thaicom 8            3100.00
# 23                         ABS-2A Eutelsat 117 West B            3600.00
# 24                                       SpaceX CRS-9            2257.00
# 25                                           JCSAT-16            4600.00
# 26                                           CASSIOPE             500.00
# 27                                            Jason-3             553.00
# 28                                     Iridium NEXT 1            9600.00
# 29                                     Iridium NEXT 2            9600.00
# 30                                         Formosat-5             475.00
# 31                                     Iridium NEXT 3            9600.00
# 32                                     Iridium NEXT 4            9600.00
# 33                                  Paz  Tintin A & B            2150.00
# 34                                     Iridium NEXT 5            9600.00
# 35                     Iridium NEXT 6   GRACE-FO 1, 2            6460.00
# 36                                      SpaceX CRS-10            2490.00
# 37                                        EchoStar 23            5600.00
# 38                                             SES-10            5300.00
# 39                                            NROL-76            3696.65
# 40                                      Inmarsat-5 F4            6070.00
# 41                                      SpaceX CRS-11            2708.00
# 42                                      BulgariaSat-1            3669.00
# 43                                       Intelsat 35e            6761.00
# 44                                      SpaceX CRS-12            3310.00
# 45                                 Boeing X-37B OTV-5            4990.00
# 46                              SES-11 / EchoStar 105            5200.00
# 47                                        Koreasat 5A            3500.00
# 48                                      Bangabandhu-1            3600.00
# 49                                      SpaceX CRS-13            2205.00
# 50                                               Zuma            3696.65
# 51                                  GovSat-1 / SES-16            4230.00
# 52                             Hispasat 30W-6  PODSat            6092.00
# 53                                      SpaceX CRS-14            2647.00
# 54       Transiting Exoplanet Survey Satellite (TESS)             362.00
# 55                                             SES-12            5384.00
#
#            Orbit                            Customer          Landing Outcome  \
# 0            LEO                              SpaceX    Failure   (parachute)
# 1      LEO (ISS)                     NASA (COTS) NRO    Failure   (parachute)
# 2      LEO (ISS)                         NASA (COTS)               No attempt
# 3      LEO (ISS)                          NASA (CRS)               No attempt
# 4      LEO (ISS)                          NASA (CRS)               No attempt
# 5            GTO                                 SES               No attempt
# 6            GTO                             Thaicom               No attempt
# 7      LEO (ISS)                          NASA (CRS)       Controlled (ocean)
# 8            LEO                             Orbcomm       Controlled (ocean)
# 9            GTO                             AsiaSat               No attempt
# 10           GTO                             AsiaSat               No attempt
# 11     LEO (ISS)                          NASA (CRS)     Uncontrolled (ocean)
# 12     LEO (ISS)                          NASA (CRS)    Failure  (drone ship)
# 13  Sun–Earth L1            U.S. Air Force NASA NOAA       Controlled (ocean)
# 14           GTO                        ABS Eutelsat               No attempt
# 15     LEO (ISS)                          NASA (CRS)    Failure  (drone ship)
# 16           GTO  Turkmenistan National Space Agency               No attempt
# 17     LEO (ISS)                          NASA (CRS)  Precluded  (drone ship)
# 18           LEO                             Orbcomm    Success  (ground pad)
# 19           GTO                                 SES     Failure (drone ship)
# 20     LEO (ISS)                          NASA (CRS)    Success  (drone ship)
# 21           GTO              SKY Perfect JSAT Group     Success (drone ship)
# 22           GTO                             Thaicom    Success  (drone ship)
# 23           GTO                        ABS Eutelsat    Failure  (drone ship)
# 24     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 25           GTO              SKY Perfect JSAT Group     Success (drone ship)
# 26     Polar LEO                                 MDA     Uncontrolled (ocean)
# 27           LEO                NASA (LSP) NOAA CNES     Failure (drone ship)
# 28     Polar LEO              Iridium Communications    Success  (drone ship)
# 29           LEO              Iridium Communications     Success (drone ship)
# 30           SSO                                NSPO     Success (drone ship)
# 31     Polar LEO              Iridium Communications     Success (drone ship)
# 32     Polar LEO              Iridium Communications       Controlled (ocean)
# 33           SSO          Hisdesat exactEarth SpaceX               No attempt
# 34     Polar LEO              Iridium Communications               No attempt
# 35     Polar LEO   Iridium Communications GFZ • NASA               No attempt
# 36     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 37           GTO                            EchoStar               No attempt
# 38           GTO                                 SES     Success (drone ship)
# 39           LEO                                 NRO     Success (ground pad)
# 40           GTO                            Inmarsat               No attempt
# 41     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 42           GTO                           Bulsatcom     Success (drone ship)
# 43           GTO                            Intelsat               No attempt
# 44     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 45           LEO                      U.S. Air Force     Success (ground pad)
# 46           GTO                        SES EchoStar     Success (drone ship)
# 47           GTO                      KT Corporation     Success (drone ship)
# 48           GTO                  Thales-Alenia/BTRC     Success (drone ship)
# 49     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 50           LEO                    Northrop Grumman     Success (ground pad)
# 51           GTO                                 SES       Controlled (ocean)
# 52           GTO                 Hispasat  NovaWurks               No attempt
# 53     LEO (ISS)                          NASA (CRS)               No attempt
# 54           HEO                          NASA (LSP)     Success (drone ship)
# 55           GTO                                 SES               No attempt
#
#     class        Lat        Long
# 0       0  28.562302  -80.577356
# 1       0  28.562302  -80.577356
# 2       0  28.562302  -80.577356
# 3       0  28.562302  -80.577356
# 4       0  28.562302  -80.577356
# 5       0  28.562302  -80.577356
# 6       0  28.562302  -80.577356
# 7       0  28.562302  -80.577356
# 8       0  28.562302  -80.577356
# 9       0  28.562302  -80.577356
# 10      0  28.562302  -80.577356
# 11      0  28.562302  -80.577356
# 12      0  28.562302  -80.577356
# 13      0  28.562302  -80.577356
# 14      0  28.562302  -80.577356
# 15      0  28.562302  -80.577356
# 16      0  28.562302  -80.577356
# 17      1  28.562302  -80.577356
# 18      1  28.562302  -80.577356
# 19      0  28.562302  -80.577356
# 20      1  28.562302  -80.577356
# 21      1  28.562302  -80.577356
# 22      1  28.562302  -80.577356
# 23      0  28.562302  -80.577356
# 24      1  28.562302  -80.577356
# 25      1  28.562302  -80.577356
# 26      0  34.632834 -120.610745
# 27      0  34.632834 -120.610745
# 28      1  34.632834 -120.610745
# 29      1  34.632834 -120.610745
# 30      1  34.632834 -120.610745
# 31      1  34.632834 -120.610745
# 32      0  34.632834 -120.610745
# 33      0  34.632834 -120.610745
# 34      0  34.632834 -120.610745
# 35      0  34.632834 -120.610745
# 36      1  28.573255  -80.646895
# 37      0  28.573255  -80.646895
# 38      1  28.573255  -80.646895
# 39      1  28.573255  -80.646895
# 40      0  28.573255  -80.646895
# 41      1  28.573255  -80.646895
# 42      1  28.573255  -80.646895
# 43      0  28.573255  -80.646895
# 44      1  28.573255  -80.646895
# 45      1  28.573255  -80.646895
# 46      1  28.573255  -80.646895
# 47      1  28.573255  -80.646895
# 48      1  28.573255  -80.646895
# 49      1  28.563197  -80.576820
# 50      1  28.563197  -80.576820
# 51      0  28.563197  -80.576820
# 52      0  28.563197  -80.576820
# 53      0  28.563197  -80.576820
# 54      1  28.563197  -80.576820
# 55      0  28.563197  -80.576820

# %%
# Which site has the largest successful launches?
largest_successful_launches_site = spacex_df[spacex_df['Class'] == 1]['Launch Site'].value_counts().idxmax()
print(f"The site with the largest number of successful launches is: {largest_successful_launches_site}")

# Which site has the highest launch success rate?
site_launch_success_rate = spacex_df.groupby('Launch Site')['Class'].mean().idxmax()
print(f"The site with the highest launch success rate is: {site_launch_success_rate}")

# Which payload range(s) has the highest launch success rate?
payload_range_success_rate = spacex_df.groupby(pd.cut(spacex_df['Payload Mass (kg)'], bins=[0, 5000, 10000, 15000, 20000, 25000, float('inf')]))['Class'].mean().idxmax()
print(f"The payload range(s) with the highest launch success rate is: {payload_range_success_rate}")

# Which payload range(s) has the lowest launch success rate?
payload_range_lowest_success_rate = spacex_df.groupby(pd.cut(spacex_df['Payload Mass (kg)'], bins=[0, 5000, 10000, 15000, 20000, 25000, float('inf')]))['Class'].mean().idxmin()
print(f"The payload range(s) with the lowest launch success rate is: {payload_range_lowest_success_rate}")

# Which F9 Booster version has the highest launch success rate?
booster_success_rate = spacex_df.groupby('Booster Version')['Class'].mean().idxmax()
print(f"The F9 Booster version with the highest launch success rate is: {booster_success_rate}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Which site has the largest successful launches?
# ----> 2 largest_successful_launches_site = spacex_df[spacex_df['Class'] == 1]['Launch Site'].value_counts().idxmax()
#       3 print(f"The site with the largest number of successful launches is: {largest_successful_launches_site}")
#       5 # Which site has the highest launch success rate?
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Class'
